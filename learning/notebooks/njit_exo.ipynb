# %%
# @title Import MuJoCo, MJX, and Brax
from datetime import datetime
import functools
import os
from typing import Any, Dict, Sequence, Tuple, Union
from brax import base
from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.base import State as PipelineState
from brax.envs.base import Env, PipelineEnv, State
from brax.io import html, mjcf, model
from brax.mjx.base import State as MjxState
from brax.training.agents.ppo import networks as ppo_networks
from brax.training.agents.ppo import train as ppo
from brax.training.agents.sac import networks as sac_networks
from brax.training.agents.sac import train as sac
from etils import epath
from flax import struct
from flax.training import orbax_utils
from IPython.display import HTML, clear_output
import jax
from jax import numpy as jp
from matplotlib import pyplot as plt
import mediapy as media
from ml_collections import config_dict
import mujoco
from mujoco import mjx
import numpy as np
from orbax import checkpoint as ocp

# %%
#@title Import The Playgroun
import sys
sys.path.insert(0, '../../../mujoco_playground')
from mujoco_playground import wrapper
from mujoco_playground import registry
from mujoco_playground.config import locomotion_params

# %%
env_name = 'NjitExoJoystickFlatTerrain'
env = registry.load(env_name)
env_cfg = registry.get_default_config(env_name)
ppo_params = locomotion_params.brax_ppo_config(env_name)

# %%
def progress(num_steps, metrics):
  clear_output(wait=True)

  times.append(datetime.now())
  x_data.append(num_steps)
  y_data.append(metrics["eval/episode_reward"])
  y_dataerr.append(metrics["eval/episode_reward_std"])

  plt.xlim([0, ppo_params["num_timesteps"] * 1.25])
  plt.xlabel("# environment steps")
  plt.ylabel("reward per episode")
  plt.title(f"y={y_data[-1]:.3f}")
  plt.errorbar(x_data, y_data, yerr=y_dataerr, color="blue")

  display(plt.gcf())

# %%
x_data, y_data, y_dataerr = [], [], []
times = [datetime.now()]

randomizer = registry.get_domain_randomizer(env_name)
ppo_training_params = dict(ppo_params)
network_factory = ppo_networks.make_ppo_networks
if "network_factory" in ppo_params:
  del ppo_training_params["network_factory"]
  network_factory = functools.partial(
      ppo_networks.make_ppo_networks,
      **ppo_params.network_factory
  )

train_fn = functools.partial(
    ppo.train, **dict(ppo_training_params),
    network_factory=network_factory,
    randomization_fn=randomizer,
    progress_fn=progress
)

# %%
make_inference_fn, params, metrics = train_fn(
    environment=env,
    eval_env=registry.load(env_name, config=env_cfg),
    wrap_env_fn=wrapper.wrap_for_brax_training,
)
print(f"time to jit: {times[1] - times[0]}")
print(f"time to train: {times[-1] - times[1]}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 make_inference_fn, params, metrics = train_fn(
#       2     environment=env,
#       3     eval_env=registry.load(env_name, config=env_cfg),
#       4     wrap_env_fn=wrapper.wrap_for_brax_training,
#       5 )
#       6 print(f"time to jit: {times[1] - times[0]}")
#       7 print(f"time to train: {times[-1] - times[1]}")
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/brax/training/agents/ppo/train.py:397, in train(environment, num_timesteps, max_devices_per_host, wrap_env, madrona_backend, augment_pixels, num_envs, episode_length, action_repeat, wrap_env_fn, randomization_fn, learning_rate, entropy_cost, discounting, unroll_length, batch_size, num_minibatches, num_updates_per_batch, num_resets_per_eval, normalize_observations, reward_scaling, clipping_epsilon, gae_lambda, max_grad_norm, normalize_advantage, network_factory, seed, use_pmap_on_reset, num_evals, eval_env, num_eval_envs, deterministic_eval, log_training_metrics, training_metrics_steps, progress_fn, policy_params_fn, save_checkpoint_path, restore_checkpoint_path, restore_params, restore_value_fn, run_evals)
#     393 key_envs = jax.random.split(key_env, num_envs // process_count)
#     394 key_envs = jnp.reshape(
#     395     key_envs, (local_devices_to_use, -1) + key_envs.shape[1:]
#     396 )
# --> 397 env_state = reset_fn(key_envs)
#     398 # Discard the batch axes over devices and envs.
#     399 obs_shape = jax.tree_util.tree_map(lambda x: x.shape[2:], env_state.obs)
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api.py:1708, in _cpp_pmap.<locals>.cache_miss(*args, **kwargs)
#    1706 try:
#    1707   if isinstance(trace, core.EvalTrace):
# -> 1708     execute = pxla.xla_pmap_impl_lazy(p.flat_fun, *p.flat_args, **params)
#    1709     out = execute(*p.flat_args)
#    1710   else:
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:353, in xla_pmap_impl_lazy(fun, backend, axis_name, axis_size, global_axis_size, devices, name, in_axes, out_axes_thunk, donated_invars, is_explicit_global_axis_size, *args)
#     351   return _emap_apply_fn
#     352 abstract_args = unsafe_map(core.abstractify, args)
# --> 353 compiled_fun, fingerprint = parallel_callable(
#     354     fun, backend, axis_name, axis_size, global_axis_size, devices, name,
#     355     in_axes, out_axes_thunk, donated_invars,
#     356     is_explicit_global_axis_size, *abstract_args)
#     358 # Don't re-abstractify args unless logging is enabled for performance.
#     359 if config.distributed_debug.value:
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:471, in cache.<locals>.memoized_fun(fun, *args)
#     469 if do_explain := explain and config.explain_cache_misses.value:
#     470   start = time.time()
# --> 471 ans = call(fun, *args)
#     472 if do_explain:
#     473   explain(fun, cache is new_cache, cache, key, time.time() - start)  # type: ignore
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:630, in parallel_callable(fun, backend_name, axis_name, axis_size, global_axis_size, devices, name, in_axes, out_axes_thunk, donated_invars, is_explicit_global_axis_size, *avals)
#     617 @lu.cache
#     618 def parallel_callable(fun: lu.WrappedFun,
#     619                       backend_name: str | None,
#    (...)
#     628                       is_explicit_global_axis_size: bool,
#     629                       *avals):
# --> 630   closed_jaxpr, xc_backend, replicas, shards, pci = get_pmap_jaxpr(
#     631       fun, backend_name, axis_name,
#     632       axis_size=axis_size, global_axis_size=global_axis_size,
#     633       devices=devices, name=fun.__name__, in_axes=in_axes,
#     634       out_axes_thunk=out_axes_thunk, avals=avals)
#     635   pmap_computation = lower_parallel_callable(
#     636       fun, axis_name, axis_size, global_axis_size, devices, name,
#     637       in_axes, donated_invars,
#    (...)
#     640       closed_jaxpr=closed_jaxpr, backend=xc_backend, replicas=replicas,
#     641       shards=shards, pci=pci)
#     642   pmap_executable = pmap_computation.compile()
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:764, in get_pmap_jaxpr(fun, backend_name, axis_name, axis_size, global_axis_size, devices, name, in_axes, out_axes_thunk, avals)
#     760 pci = ParallelCallableInfo(
#     761     name, backend, axis_name, axis_size, global_axis_size, devices,
#     762     in_axes, out_axes_thunk, avals)
#     763 with core.extend_axis_env_nd([(axis_name, axis_size)]):
# --> 764   jaxpr, consts, replicas, shards = stage_parallel_callable(pci, fun)
#     765 jaxpr = core.remove_named_axis_effects(jaxpr, {axis_name})
#     766 closed_jaxpr = core.ClosedJaxpr(jaxpr, consts)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:727, in stage_parallel_callable(pci, fun)
#     723 with core.extend_axis_env_nd([(pci.axis_name, pci.global_axis_size)]):
#     724   with dispatch.log_elapsed_time(
#     725       "Finished tracing + transforming {fun_name} for pmap in {elapsed_time} sec",
#     726       fun_name=fun.__name__, event=dispatch.JAXPR_TRACE_EVENT):
# --> 727     jaxpr, out_sharded_avals, consts, _ = pe.trace_to_jaxpr_dynamic(
#     728         fun, sharded_avals)
#     730 assert len(out_sharded_avals) == len(pci.out_axes), (
#     731     len(out_sharded_avals), len(pci.out_axes))
#     733 replicas = find_replicas(jaxpr, pci.axis_size, pci.global_axis_size)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2292, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower)
#    2290 try:
#    2291   with core.set_current_trace(trace):
# -> 2292     ans = fun.call_wrapped(*in_tracers)
#    2293   _check_returned_jaxtypes(fun.debug_info, ans)
#    2294   out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:703, in _change_argument_ranks(f, in_axes, out_axes_thunk, *args)
#     698 from jax._src.lax import lax  # pytype: disable=import-error
#     699 args = tuple(
#     700     arg if in_axis is None else lax.squeeze(arg, dimensions=(in_axis,))
#     701     for in_axis, arg in zip(in_axes, args)
#     702 )
# --> 703 results = f(*args)
#     704 out_axes = out_axes_thunk()
#     705 return tuple(
#     706     x if axis is None else lax.expand_dims(x, dimensions=(axis,))
#     707     for x, axis in zip(results, out_axes)
#     708 )
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api_util.py:439, in _flat_out_axes(_fun, _store, _leaves, _treedef, *args, **kwargs)
#     437 @lu.transformation_with_aux2
#     438 def _flat_out_axes(_fun, _store, _leaves, _treedef, *args, **kwargs):
# --> 439   ans = _fun(*args, **kwargs)
#     440   spec = tree_unflatten(_treedef, _leaves)
#     441   try:
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# File ~/BioDynamic/mujoco_playground/learning/notebooks/../../../mujoco_playground/mujoco_playground/_src/wrapper.py:157, in BraxAutoResetWrapper.reset(self, rng)
#     155 rng_key = jax.vmap(jax.random.split)(rng)
#     156 rng, key = rng_key[..., 0], rng_key[..., 1]
# --> 157 state = self.env.reset(key)
#     158 state.info[f'{self._info_key}_first_data'] = state.data
#     159 state.info[f'{self._info_key}_first_obs'] = state.obs
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/brax/envs/wrappers/training.py:84, in EpisodeWrapper.reset(self, rng)
#      83 def reset(self, rng: jax.Array) -> State:
# ---> 84   state = self.env.reset(rng)
#      85   state.info['steps'] = jp.zeros(rng.shape[:-1])
#      86   state.info['truncation'] = jp.zeros(rng.shape[:-1])
#
# File ~/BioDynamic/mujoco_playground/learning/notebooks/../../../mujoco_playground/mujoco_playground/_src/wrapper.py:243, in BraxDomainRandomizationVmapWrapper.reset(self, rng)
#     240   with self.v_env_fn(mjx_model) as v_env:
#     241     return v_env.reset(rng)
# --> 243 state = jax.vmap(reset, in_axes=[self._in_axes, 0])(self._mjx_model_v, rng)
#     244 return state
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api.py:1129, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1126 try:
#    1127   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1128                                 explicit_mesh_axis)
# -> 1129   out_flat = batching.batch(
#    1130       flat_fun, axis_data, in_axes_flat,
#    1131       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1132   ).call_wrapped(*args_flat)
#    1133 except batching.SpecMatchError as e:
#    1134   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:618, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     616 tag = TraceTag()
#     617 with source_info_util.transform_name_stack('vmap'):
# --> 618   outs, trace = f(tag, in_dims, *in_vals)
#     619 with core.ensure_no_leaks(trace): del trace
#     620 return outs
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:634, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     630   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     631 with (core.set_current_trace(trace),
#     632       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     633       core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 634   outs = f(*in_tracers)
#     635   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     636   out_vals = map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis),
#     637                  range(len(outs)), outs, out_dim_dests)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:342, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     338 @lu.transformation_with_aux2
#     339 def flatten_fun_for_vmap(f: Callable,
#     340                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     341   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 342   ans = f(*py_args, **py_kwargs)
#     343   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     344   store.store(out_tree)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# File ~/BioDynamic/mujoco_playground/learning/notebooks/../../../mujoco_playground/mujoco_playground/_src/wrapper.py:241, in BraxDomainRandomizationVmapWrapper.reset.<locals>.reset(mjx_model, rng)
#     239 def reset(mjx_model, rng):
#     240   with self.v_env_fn(mjx_model) as v_env:
# --> 241     return v_env.reset(rng)
#
# File ~/BioDynamic/mujoco_playground/learning/notebooks/../../../mujoco_playground/mujoco_playground/_src/locomotion/njit_exo/joystick.py:223, in Joystick.reset(self, rng)
#     210 qvel = qvel.at[0:6].set(
#     211     jax.random.uniform(key, (6,), minval=-0.5, maxval=0.5)
#     212 )
#     214 data = mjx_env.make_data(
#     215     self.mj_model,
#     216     qpos=qpos,
#    (...)
#     221     njmax=self._config.njmax,
#     222 )
# --> 223 data = mjx.forward(self.mjx_model, data)
#     225 # Phase, freq=U(1.0, 1.5)
#     226 rng, key = jax.random.split(rng)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/forward.py:63, in named_scope.<locals>.wrapper(*args, **kwargs)
#      60 @functools.wraps(fn)
#      61 def wrapper(*args, **kwargs):
#      62   with jax.named_scope(name or getattr(fn, '__name__')):
# ---> 63     res = fn(*args, **kwargs)
#      64   return res
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/forward.py:438, in forward(m, d)
#     435 if not isinstance(m._impl, ModelJAX) or not isinstance(d._impl, DataJAX):
#     436   raise ValueError('forward requires JAX backend implementation.')
# --> 438 d = fwd_position(m, d)
#     439 d = sensor.sensor_pos(m, d)
#     440 d = fwd_velocity(m, d)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/forward.py:63, in named_scope.<locals>.wrapper(*args, **kwargs)
#      60 @functools.wraps(fn)
#      61 def wrapper(*args, **kwargs):
#      62   with jax.named_scope(name or getattr(fn, '__name__')):
# ---> 63     res = fn(*args, **kwargs)
#      64   return res
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/forward.py:82, in fwd_position(m, d)
#      80 d = collision_driver.collision(m, d)
#      81 d = constraint.make_constraint(m, d)
# ---> 82 d = smooth.transmission(m, d)
#      83 return d
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/smooth.py:1291, in transmission(m, d)
#    1288 site_dof_mask = _site_dof_mask(m)
#    1289 site_quat = jax.vmap(math.quat_mul)(m.site_quat, d.xquat[m.site_bodyid])
# -> 1291 length, moment = scan.flat(
#    1292     m,
#    1293     fn,
#    1294     'uuujjquusss',
#    1295     'uu',
#    1296     m.actuator_trntype,
#    1297     jp.array(m.actuator_trnid),
#    1298     m.actuator_gear,
#    1299     m.jnt_type,
#    1300     jp.array(m.jnt_dofadr),
#    1301     d.qpos,
#    1302     has_refsite,
#    1303     jp.array(site_dof_mask),
#    1304     d.site_xpos,
#    1305     d.site_xmat,
#    1306     site_quat,
#    1307     group_by='u',
#    1308 )
#    1309 length = length.reshape((m.nu,))
#    1310 moment = moment.reshape((m.nu, m.nv))
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/scan.py:331, in flat(m, f, in_types, out_types, group_by, *args)
#     329   ids = np.concatenate([np.hstack(v[typ]) for _, v in key_typ_ids])
#     330   input_order = order[typ][np.where(order[typ] != -1)]
# --> 331   reordered_ys.append(_take(y, _index(ids, input_order)))
#     332 y = reordered_ys if f_ret_is_seq else reordered_ys[0]
#     334 return y
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/scan.py:65, in _take(obj, idx)
#      62     x = x.take(jp.array(idx), axis=0, mode='wrap')
#      63   return x
# ---> 65 return jax.tree_util.tree_map(take, obj)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/tree_util.py:362, in tree_map(f, tree, is_leaf, *rest)
#     360 leaves, treedef = tree_flatten(tree, is_leaf)
#     361 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 362 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/tree_util.py:362, in <genexpr>(.0)
#     360 leaves, treedef = tree_flatten(tree, is_leaf)
#     361 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 362 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/mujoco/mjx/_src/scan.py:62, in _take.<locals>.take(x)
#      60   x = x[idx[0] : idx[-1] + 1]
#      61 else:
# ---> 62   x = x.take(jp.array(idx), axis=0, mode='wrap')
#      63 return x
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:389, in _take(self, indices, axis, out, mode, unique_indices, indices_are_sorted, fill_value)
#     382 def _take(self: Array, indices: ArrayLike, axis: int | None = None, out: None = None,
#     383           mode: str | None = None, unique_indices: bool = False, indices_are_sorted: bool = False,
#     384           fill_value: StaticScalar | None = None) -> Array:
#     385   """Take elements from an array.
#     386
#     387   Refer to :func:`jax.numpy.take` for full documentation.
#     388   """
# --> 389   return indexing.take(self, indices, axis=axis, out=out, mode=mode, unique_indices=unique_indices,
#     390                        indices_are_sorted=indices_are_sorted, fill_value=fill_value)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:130, in take(a, indices, axis, out, mode, unique_indices, indices_are_sorted, fill_value)
#      47 @export
#      48 def take(
#      49     a: ArrayLike,
#    (...)
#      56     fill_value: StaticScalar | None = None,
#      57 ) -> Array:
#      58   """Take elements from an array.
#      59
#      60   JAX implementation of :func:`numpy.take`, implemented in terms of
#    (...)
#     128            [1., 2., 3.]], dtype=float32)
#     129   """
# --> 130   return _take(a, indices, None if axis is None else operator.index(axis), out,
#     131                mode, unique_indices=unique_indices, indices_are_sorted=indices_are_sorted,
#     132                fill_value=fill_value)
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:292, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     287 if config.no_tracing.value:
#     288   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     289                      "`jit`, but 'no_tracing' is set")
#     291 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, box_data,
# --> 292  executable, pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     294 maybe_fastpath_data = _get_fastpath_data(
#     295     executable, out_tree, args_flat, out_flat, attrs_tracked, box_data,
#     296     jaxpr.effects, jaxpr.consts, jit_info.abstracted_axes, pgle_profiler)
#     298 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:139, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     138 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 139   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     141   for arg in args_flat:
#     142     dispatch.check_arg(arg)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:686, in _infer_params(fun, ji, args, kwargs)
#     683   with (_internal_use_concrete_mesh(phys_mesh),
#     684         mesh_lib.use_abstract_mesh(phys_mesh.abstract_mesh)):
#     685     return _infer_params_internal(fun, ji, args, kwargs)
# --> 686 return _infer_params_internal(fun, ji, args, kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:710, in _infer_params_internal(fun, ji, args, kwargs)
#     707 entry = _infer_params_cached(fun, ji, signature, avals, ctx_mesh)
#     709 if entry.pjit_params is None:
# --> 710   p, args_flat = _infer_params_impl(
#     711       fun, ji, ctx_mesh, dbg, args, kwargs, in_avals=avals)
#     712   if p.attrs_tracked or p.box_data or p.params['jaxpr'].jaxpr.is_high:
#     713     return p, p.consts + args_flat
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:606, in _infer_params_impl(***failed resolving arguments***)
#     599 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     600     in_shardings_treedef, in_shardings_leaves,
#     601     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     602     in_avals, in_tree, flat_fun.debug_info, device_or_backend_set, have_kwargs)
#     604 attr_token = _attr_cache_index(flat_fun, in_type)
# --> 606 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     607     flat_fun, in_type, attr_token, IgnoreKey(ji.inline))
#     609 if config.mutable_array_checks.value:
#     610   _check_no_aliased_closed_over_refs(dbg, (*jaxpr.consts, *consts), explicit_args)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:471, in cache.<locals>.memoized_fun(fun, *args)
#     469 if do_explain := explain and config.explain_cache_misses.value:
#     470   start = time.time()
# --> 471 ans = call(fun, *args)
#     472 if do_explain:
#     473   explain(fun, cache is new_cache, cache, key, time.time() - start)  # type: ignore
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:1414, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1412     attrs_tracked = []
#    1413   else:
# -> 1414     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(fun, in_type)
#    1416 if config.debug_key_reuse.value:
#    1417   # Import here to avoid circular imports
#    1418   from jax.experimental.key_reuse._core import check_key_reuse_jaxpr  # pytype: disable=import-error
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2292, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower)
#    2290 try:
#    2291   with core.set_current_trace(trace):
# -> 2292     ans = fun.call_wrapped(*in_tracers)
#    2293   _check_returned_jaxtypes(fun.debug_info, ans)
#    2294   out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api_util.py:314, in _argnames_partial(_fun, _fixed_kwargs, *args, **dyn_kwargs)
#     311 @lu.transformation2
#     312 def _argnames_partial(_fun, _fixed_kwargs: WrapKwArgs, *args, **dyn_kwargs):
#     313   kwargs = dict({k: v.val for k, v in _fixed_kwargs.val.items()}, **dyn_kwargs)
# --> 314   return _fun(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:156, in _take(a, indices, axis, out, mode, unique_indices, indices_are_sorted, fill_value)
#     154   raise NotImplementedError("The 'raise' mode to jnp.take is not supported.")
#     155 elif mode == "wrap":
# --> 156   indices = ufuncs.mod(indices, lax_internal._const(indices, a.shape[axis_idx]))
#     157   gather_mode = lax.GatherScatterMode.PROMISE_IN_BOUNDS
#     158 elif mode == "clip":
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/numpy/ufuncs.py:3137, in mod(x1, x2)
#    3134 @export
#    3135 def mod(x1: ArrayLike, x2: ArrayLike, /) -> Array:
#    3136   """Alias of :func:`jax.numpy.remainder`"""
# -> 3137   return remainder(x1, x2)
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:292, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     287 if config.no_tracing.value:
#     288   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     289                      "`jit`, but 'no_tracing' is set")
#     291 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, box_data,
# --> 292  executable, pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     294 maybe_fastpath_data = _get_fastpath_data(
#     295     executable, out_tree, args_flat, out_flat, attrs_tracked, box_data,
#     296     jaxpr.effects, jaxpr.consts, jit_info.abstracted_axes, pgle_profiler)
#     298 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File /opt/anaconda3/envs/learnRL/lib/python3.10/site-packages/jax/_src/pjit.py:138, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     134   def __eq__(self, other):
#     135     return self is other
# --> 138 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
#     139   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     141   for arg in args_flat:
#
# KeyboardInterrupt:

# %%
#@title Rollout and Render
from mujoco_playground._src.gait import draw_joystick_command

env = registry.load(env_name)
eval_env = registry.load(env_name)
jit_reset = jax.jit(eval_env.reset)
jit_step = jax.jit(eval_env.step)
jit_inference_fn = jax.jit(make_inference_fn(params, deterministic=True))

rng = jax.random.PRNGKey(1)

rollout = []
modify_scene_fns = []

x_vel = 1.0  #@param {type: "number"}
y_vel = 0.0  #@param {type: "number"}
yaw_vel = 0.0  #@param {type: "number"}
command = jp.array([x_vel, y_vel, yaw_vel])

phase_dt = 2 * jp.pi * eval_env.dt * 1.5
phase = jp.array([0, jp.pi])

for j in range(1):
  print(f"episode {j}")
  state = jit_reset(rng)
  state.info["phase_dt"] = phase_dt
  state.info["phase"] = phase
  for i in range(env_cfg.episode_length):
    act_rng, rng = jax.random.split(rng)
    ctrl, _ = jit_inference_fn(state.obs, act_rng)
    state = jit_step(state, ctrl)
    if state.done:
      break
    state.info["command"] = command
    rollout.append(state)

    xyz = np.array(state.data.xpos[eval_env.mj_model.body("exo_pelvis").id])
    xyz += np.array([0, 0.0, 0])
    x_axis = state.data.xmat[eval_env._pelvis_body_id, 0]
    yaw = -np.arctan2(x_axis[1], x_axis[0])
    modify_scene_fns.append(
        functools.partial(
            draw_joystick_command,
            cmd=state.info["command"],
            xyz=xyz,
            theta=yaw,
            scl=np.linalg.norm(state.info["command"]),
        )
    )

render_every = 1
fps = 1.0 / eval_env.dt / render_every
print(f"fps: {fps}")
traj = rollout[::render_every]
mod_fns = modify_scene_fns[::render_every]

scene_option = mujoco.MjvOption()
scene_option.geomgroup[2] = True
scene_option.geomgroup[3] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True
scene_option.flags[mujoco.mjtVisFlag.mjVIS_TRANSPARENT] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_PERTFORCE] = False

frames = eval_env.render(
    traj,
    camera="track",
    scene_option=scene_option,
    width=640*2,
    height=480,
    modify_scene_fns=mod_fns,
)
media.show_video(frames, fps=fps, loop=False)
